# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path
import matplotlib.pyplot as plt

# %%
data_dir = Path(os.getenv("OODIR"))

year = 1980
month = 12

# %%
df = pd.read_csv(data_dir / "ICOADS" / f"icoads_{year}{month:02d}.csv")
selection = df['lon'] > 180
df.loc[selection, 'lon'] = df[selection]['lon'] - 360

# %%
selection = (
(df['lat'] <= -65) &
(df['lat'] <= -70) &
(df['lat'] <= -30) &
(df['lat'] <= -25)
)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
print(df[selection])
# Out:
#         Unnamed: 0     uid  year  month   day   lat   lon  sst         id  hour    at   si  sid  dck   c1   pt  sim  snc trackid
# 88727       105502  24KNXT  1980     12  12.0 -70.3 -11.0  0.0  UZAE       18.0   1.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 90657       107736  24KPL5  1980     12  13.0 -70.6 -10.8  0.0  UZAE        0.0  -4.6  9.0   29  892  NaN  5.0  C      1    UZAE
# 92447       109845  24KR59  1980     12  13.0 -70.8 -10.9  0.0  UZAE        6.0  -2.1  9.0   29  892  NaN  5.0  C      1    UZAE
# 94263       111982  24KSPM  1980     12  13.0 -71.0 -11.3  0.0  UZAE       12.0   0.4  9.0   29  892  NaN  5.0  C      1    UZAE
# 97991       116359  24KVWI  1980     12  14.0 -71.2 -13.2  0.0        NaN   0.0  -4.0  NaN   57  732  NaN  5.0  NaN    1     NaN
# 99768       118455  24KXG4  1980     12  14.0 -72.3 -16.3  0.0  UZAE        6.0   1.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 101589      120586  24KZ03  1980     12  14.0 -72.3 -16.9  0.0        NaN  12.0   1.0  NaN   57  732  NaN  5.0  NaN    1     NaN
# 103414      122755  24L0L1  1980     12  14.0 -72.9 -19.7  0.0        NaN  18.0  -1.0  NaN   57  732  NaN  5.0  NaN    1     NaN
# 105273      124905  24L253  1980     12  15.0 -73.9 -21.8  0.0  UZAE        0.0  -3.8  9.0   29  892  NaN  5.0  C      1    UZAE
# 106989      126933  24L3MP  1980     12  15.0 -74.3 -25.0  0.0  UZAE        6.0  -3.6  9.0   29  892  NaN  5.0  C      1    UZAE
# 108732      128970  24L53V  1980     12  15.0 -74.5 -25.7  0.0        NaN  12.0  -0.2  NaN   57  732  NaN  5.0  NaN    1     NaN
# 112372      133241  24L881  1980     12  16.0 -74.5 -25.6  0.0  UZAE        0.0  -5.4  9.0   29  892  NaN  5.0  C      1    UZAE
# 114097      135276  24L9Q0  1980     12  16.0 -74.5 -25.4  0.0  UZAE        6.0  -4.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 115838      137344  24LB8D  1980     12  16.0 -74.5 -25.4  0.0        NaN  12.0  -3.9  NaN   57  732  NaN  5.0  NaN    1     NaN
# 119463      141587  24LECF  1980     12  17.0 -74.5 -25.4  0.0  UZAE        0.0  -5.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 121159      143623  24LFUE  1980     12  17.0 -74.5 -25.4  0.0  UZAE        6.0  -3.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 122922      145742  24LHDT  1980     12  17.0 -74.5 -25.4  0.0  UZAE       12.0  -3.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 124706      147856  24LIXG  1980     12  17.0 -74.5 -25.4  0.0  UZAE       18.0  -1.6  9.0   29  892  NaN  5.0  C      1    UZAE
# 126582      150059  24LKJN  1980     12  18.0 -74.5 -25.4  0.0  UZAE        0.0   0.4  9.0   29  892  NaN  5.0  C      1    UZAE
# 128310      152106  24LM1Z  1980     12  18.0 -74.5 -25.4  0.0  UZAE        6.0  -3.0  NaN   79  888  NaN  5.0  C      1    UZAE
# 130087      154177  24LNKM  1980     12  18.0 -74.5 -25.4  0.0        NaN  12.0  -3.2  NaN   57  732  NaN  5.0  NaN    1     NaN
# 131893      156292  24LP4M  1980     12  18.0 -74.5 -25.4  0.0  UZAE       18.0  -2.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 133812      158499  24LQQS  1980     12  19.0 -73.9 -21.8  0.0        NaN   0.0  -3.8  NaN   57  732  NaN  5.0  NaN    1     NaN
# 133813      158500  24LQQR  1980     12  19.0 -74.5 -25.4  0.0        NaN   0.0   2.5  NaN   57  732  NaN  5.0  NaN    1     NaN
# 135573      160561  24LS9K  1980     12  19.0 -74.5 -25.4  0.0  UZAE        6.0  -3.3  9.0   29  892  NaN  5.0  C      1    UZAE
# 137290      162590  24LTR0  1980     12  19.0 -74.5 -25.4  0.0        NaN  12.0  -1.4  NaN   57  732  NaN  5.0  NaN    1     NaN
# 139064      164649  24LV97  1980     12  19.0 -74.6 -25.5  0.0  UZAE       18.0  -1.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 140911      166799  24LWTN  1980     12  20.0 -74.7 -25.8  0.0  UZAE        0.0  -4.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 153260      181240  24M7EU  1980     12  21.0 -76.7 -32.5  0.0  UZAE       18.0  -0.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 155035      183244  24M8VL  1980     12  22.0 -77.6 -35.3  0.0  UZAE        0.0  -1.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 180004      212285  24MU5X  1980     12  25.0 -72.3 -16.8  0.0  UPPB       18.0  -3.0  9.0   29  892  NaN  5.0  NaN    1    UPPB
# 205716      242302  24NG57  1980     12  29.0 -77.6 -42.4 -0.7  UZAE       18.0  -4.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 207424      244288  24NHLG  1980     12  30.0 -77.7 -43.6 -1.0  UZAE        0.0  -2.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 208982      246150  24NIYV  1980     12  30.0 -77.7 -43.2 -1.0        NaN   6.0  -2.3  NaN   57  732  NaN  5.0  NaN    1     NaN
# 210561      248004  24NKB4  1980     12  30.0 -77.6 -42.3 -1.0        NaN  12.0  -2.5  NaN   57  732  NaN  5.0  NaN    1     NaN
# 212210      249957  24NLQ8  1980     12  30.0 -77.6 -43.1 -1.0  UZAE       18.0  42.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 213922      251984  24NN7D  1980     12  31.0 -77.7 -44.0 -1.0  UZAE        0.0   1.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 215533      253864  24NOL6  1980     12  31.0 -70.0 -10.5 -1.5  00227       6.0  -1.0  0.0   90  254   21  5.0  NaN    1     NaN
# 215534      253865  24NOL5  1980     12  31.0 -77.6 -33.2 -1.0  UZAE        6.0  -6.0  9.0   29  892  NaN  5.0  C      1    UZAE
# 217156      255768  24NPYN  1980     12  31.0 -70.9 -12.3 -2.0  00227      12.0  -1.5  0.0   90  254   21  5.0  NaN    1     NaN
# 217157      255769  24NPYM  1980     12  31.0 -77.7 -43.1 -1.0  UZAE       12.0  -3.2  9.0   29  892  NaN  5.0  C      1    UZAE
# 218704      257625  24NRBE  1980     12  31.0 -71.7 -15.7 -1.5  DLDZ       18.0   5.5  9.0   29  892  NaN  5.0  BU     1    DLDZ
# 218705      257626  24NRBD  1980     12  31.0 -77.6 -43.4 -1.0  UZAE       18.0   2.9  9.0   29  892  NaN  5.0  C      1    UZAE
# 218706      257627  24NRBC  1980     12  31.0 -77.7 -43.4 -1.0        NaN  18.0   1.9  NaN   57  732  NaN  5.0  NaN    1     NaN
